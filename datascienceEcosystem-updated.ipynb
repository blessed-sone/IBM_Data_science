# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ___Module 6___

# %% [markdown]
# ![2-title.png](attachment:2-title.png)

# %% [markdown]
# ___Introduction___

# %% [markdown]
# This not book summarizes the data science tools and libraries. In each category, just about 3 items will be listed.

# %% [markdown]
# ### Peer Graded Assignment

# %% [markdown]
# #### Exercise 2 : Data Science Ecosystem

# %% [markdown]
# #### Exercise 3: Introduction
#
# This exercise summarizes the concepts learned in module 6 and course two entitled "Data Science Tools". We won't recopy the questions of each exercise except the exercise number and the corresponding answers.

# %% [markdown]
# #### Exercise 4: Data science languages
#
# 1. python
# 2. R
# 3. sql

# %% [markdown]
# #### Exercise 5: Data science libraries
#
# pandas
#
# matplot

# %% [markdown]
# #### Exercise 6: table of Data Science tools.
# |Data Science Task Categories | Open Source Tools | Proprietary Tools |
# |-----------------------------|-------------------|-------------------|
# |Data Management| Mysql, MongoDB, Cassandra, CouchDB|Oracle DB,Azure|
# |Data Integration and Transformation | Apache Airflow, Kubeflow, Apache Kafka| -----|
# |Data Visualization | PixieDust, Kibana. |----- |

# %% [markdown]
# #### Exercise 7: Arithemetic Expressions

# %%
7 * 8
# Out:
# 56

# %% [markdown]
# #### Exercise 8: Multiply and add two numbers

# %%
a = int(input(">"))
b = int(input(">"))
sumResult = a + b
multiResult = a * b
print(f"the sum is: {sumResult}")
print(f"the multiple is: {multiResult}")
# Out:
# >89
# >90
# the sum is: 179
# the multiple is: 8010

# %% [markdown]
# #### Exercise 9: Converting minutes to hours

# %%
minutes = int(input("Enter minutes:> "))
hours = minutes / 60
print(hours)
# Out:
# Enter minutes:> 456
# 7.6

# %% [markdown]
# #### Exercise 10: list of objectives

# %% [markdown]
# At the end of the exercise, we shall be able to:
# 1. Create a Jupiter Notebook and Save it
# 2. Add content in the code and markdown cells
# 3. Insert images into a Notebook.
# 4. Upload Notebook to github

# %% [markdown]
# #### Exercise 11: Author's name: SONE ERIC EBOMBE
# [Portfolio](https://github.com/blessed-sone/Portfolio)
